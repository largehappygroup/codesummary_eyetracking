# %% [markdown]
# - This script splits bounding boxes that have a function call
# using the dot operator.
# - For mapping bounding boxes to parts of the code, it's easier
# to separate these than it is to leave them in.
# - That's because scrML splits these as it makes the ASTs
# - (e.g. clock.getCurrentTime --> 'clock', '.', 'getCurrentTime')

# %%
import os
import re
import cv2
import pandas as pd
import numpy as np

# %%
box_files = os.listdir("./word_coordinates_final/")

# %%
for file in box_files:
    name = re.sub("_boxes.csv", "", file)
    boxes = pd.read_csv(f'./word_coordinates_final/{file}')
    for i, row in boxes.iterrows():
        word = row['word']
        if isinstance(word, str) and re.search("\.", word):
            dot_found = re.search("\.", word)
            print(word, dot_found.start())
        #print(row['word'])
# Out:
# "P/x.ctx" 4
# ctx.save 3
# "P/y.ctx" 4
# cty.save 3
# "P/z.ctx" 4
# ctz.save 3
# "P/x.ctx" 4
# /P/x.csc" 4
# "P/y.ctx" 4
# "P/z.ctx" 4
# /P/z.csc" 4
# System.out.println 6
# instance.getEmail 8
# fail. 4
# prototype." 9
# targets.get 7
# targets.set 7
# targets.get 7
# targets.set 7
# log.debug 3
# targets.size 7
# log.debug 3
# targets.get 7
# ref.getFile 3
# spp.printCUnit 3
# spp.close 3
# ioe.printStackTrace 3
# System.err.println 6
# ref.getFile 3
# containerName.equals 13
# window.setParent 6
# OrganiserView.this 13
# window.doModal 6
# ie.printStackTrace 2
# System.err 6
# importer.setcontainerName 8
# window.getName 6
# importer.setContainerDescription 8
# window.getDescription 6
# loc.x 3
# loc.y 3
# frame.setState 5
# Frame.ICONIFIED 5
# "".equals 2
# "".equals 2
# !val.equals 4
# n.adjEdges.elements 1
# es.hasMoreElements 2
# n.adjNode 1
# )es.nextElement 3
# n2.dist 2
# n2.dist 2
# n.dist 1
# n2.dist 2
# ToDo.add 4
# !ToDo.isEmpty 5
# ToDo.remove 4
# System.out.println 6
# instance.setEvtID 8
# fail. 4
# prototype." 9
# System.out.print 6
# System.out.print 6
# System.out.print 6
# System.out.print 6
# System.out.print 6
# System.out.println 6
# t.printStackTrace 1
# this.value 4
# o.value 1
# this.tstamp 4
# o.tstamp 1
# this.tstamp 4
# o.tstamp 1
# this.tstamp 4
# o.tstamp 1
# this.value 4
# o.value 1
# pack.append 4
# ).nl 1
# dates.contains 5
# dates.size 5
# dates.get 5
# date.before 4
# dates.add 5
# dates.add 5
# ResourceUtils.createContext 13
# context.getConstant 7
# context.getAxiom 7
# indexer.index 7
# tk.assertOccurrencesOtherThanDecl 2
# SimulatorState.STOPPED 14
# simItem.initialize 7
# SimulatorState.PLAYING 14
# SimulatorState.PAUSED 14
# SimulatorState.PLAYING 14
# servletRequest.getCookies 14
# cookie.getName().equals 6
# "platform.username" 9
# cookie.getValue 6
# DesEncrypter.getInstance 12
# NodeImpl.build 8
# XMLParserImpl.setNamedItem 13
# this.getJsObject 4
# ).getJsObject 1
# DOMNodeException.INVALID_MODIFICATION_ERR 16
# headers.getTo 7
# toURI.getPath 5
# to.substring 2
# to.lastIndexOf 2
# lfNameToLookAndFeel.containsKey 19
# UIManager.LookAndFeeIInfo 9
# UIManager.LookAndFeeIInfo 9
# lfNameToLookAndFeel.get 19
# lookAndFeelInfo.getClassName 15
# filter.setLayoutIndex 6
# filter.getLayoutIndex 6
# filter.getLayoutIndex 6
# fieldList.getValueAt 9
# ).toString 1
# Assertions. 10
# null." 4
# entitySel.remove 9
# selection.getEntityId 9
# selection.getType().equals 9
# EntityType.MEMBER 10
# booleanAtom.getBooleanValue 11
# atom.getValue 4
# atom.getValue 4
# file.setPosition 4
# file.read 4
# DbfUtils.decodeLittleUint16 8
# DbfUtils.decodeLittleUint16 8
# DbfUtils.decodeLittleUint16 8
# Belvedere4.mrjVersion 10
# System.getProperty 6
# "mrj.version" 4
# Belvedere4.mrjVersion 10
# Belvedere4.mrjMajorVersion 10
# Double.valueOf 6
# Belvedere4.mrjVersion.substring 10
# )).doubleValue 2
# Belvedere4.mrjMajorVersion 10
# log.entering 3
# propDlg.setModal 7
# propDlg.setVisible 7
# log.exiting 3
# transport.setRemoteService 9
# call.setOperation 4
# call.addParameter 4
# XMLType.XSD_STRING 7
# ParameterMode.IN 13
# call.setReturnType 4
# XMLType.XSD_STRING 7
# call.invoke 4
# p.addSelectionChangeListener 1
# jSplitPane.setLeftComponent 10
# jSplitPane.setRightComponent 10
# jSplitPane.setDividerSize 10
# jSplitPane.setDividerLocation 10
# connectionRoomLabel.setText 19
# connectionPanel.setLayout 15
# BoxLayout.X_AXIS 9
# connectionPanel.add 15
# connectionPanel.add 15
# System.arraycopy 6
# olduis.length 6
# Math.random 4
# utils.setGlobal 5
# s.length 1
# s.substring 1
# ).equals 1
# s.substring 1
# ).toUpperCase 1
# s.substring 1
# menuAdministracion.setText 18
# Messages.getString 8
# "gui.GUI.57" 4
# menuAdministracion.setIcon 18
# "data/icons/package_system.png" 26
# menuAdministracion.add 18
# menuAdministracion.add 18
# pride2Broker.getCount 12
# eop.tailSet 3
# ).first 1
# eop.headSet 3
# ).last 1
# q.getRotationMatrix 1
# Matrix.multiply 6
# q.getRotationMatrix 1
# string.getBytes 6
# ex.printStackTrace 2
# messages.size 8
# messages.elementAt 8
# sb.append 2
# o.toString 1
# sb.append 2
# sb.toString 2
# tok.countTokens 3
# tok.hasMoreTokens 3
# result.add 6
# tok.nextToken 3
# process.eAllContents 7
# contents.hasNext 8
# contents.next 8
# results.addAll 7
# getScopePartnerLinks().getChildren 22
# stmt.sub().paths().iterator 4
# iter.hasNext 4
# iter.next 4
# targets.add 7
# targets.addAll 7
# stmt.catchTargets 4
# stmt.block 4
# prop.setProperty 4
# "avalanchefever.gametype" 15
# prop.setProperty 4
# "avalanchefever.outlinetype" 15
# prop.setProperty 4
# "avalanchefever.numcolors" 15
# prop.setProperty 4
# "avalanchefever.version" 15
# prop.setProperty 4
# "avalanchefever.chainDisplayType" 15
# prop.setProperty 4
# "avalanchefever.bigDisplay" 15
# s.simpleSelector.equals 1
# s.condition.equals 1
# System.out.println 6
# tag.setExample 3
# tag.getExample 3
# multiSubmitButton.requestFocusInWindow 17
# multipleGUIList.clearSelection 15
# logger.warn 6
# info.getName 4
# info.isRemoveOnExceptions 4
# event.getSource 5
# logger.warn 6
# InfluenceLaw.iterator 12
# iter.hasNext 4
# iter.next 4
# infLaw.isApplicableTo 6
# this.credentials 4
# this.username 4
# br.readLine 2
# this.password 4
# br.readLine 2
# br.close 2
# fr.close 2
# this.username 4
# this.password 4
# logger.debug 6
# them. 4
# refresh." 7
# logger.warn 6
# e.getMessage 1
# Collections.EMPTY_LIST 11
# codes. 5
# .getIdent 0
# VKUtils.createArray 7
# CStdType.String 8
# han.getLatestNutritionPlan 3
# NutritionController.editPlan 19
# WebPlanProtocol.createPlan 15
# e.printStackTrace 1
# logger.fine 6
# this.contact 4
# Context.mainFrame 7
# optionPane.setValue 10
# JOptionPane.UNINITIALIZED_VALUE 11
# panel.setContact 5
# panel.prepareForShow 5
# from.getLength 4
# topMenu.setAttribute 7
# from.getLocalName 4
# from.getValue 4
# topMenu.setAttribute 7
# from.getQName 4
# from.getValue 4
# ... 0
# errors.get 6
# property... 8
# ... 0
# errors.put 6
# set." 3
# context.getContentResolver().query 7
# .query 0
# Sources.SourcesTable.NAME 7
# System.out.println 6
# cfg.visit 3
# super.visitBlock 5
# super.visitLabelStmt 5
# .startsBlock 0
# System.out.println 6
# !objectpath.matches 11
# re.getIngredients 2
# iam.getFood 3
# )iam.getFood 4
# iam.getFood 3
# Command.BACK 7
# registry.iterator 8
# iter.hasNext 4
# )iter.next 5
# node.plugin.getName 4
# .equals 0
# LoadService.currentlyWritingFile 11
# LoadService.SERVICE_NODE_DESCRIPTION_FILE 11
# out.writeObject 3
# out.flush 3
# out.close 3
# e1.printStackTrace 2
# e1.printStackTrace 2
# LoadService.currentlyWritingFile 11
# defender.getXpos 8
# defender.getYpos 8
# listData.size 8
# listData.size 8
# listData.get 8
# auditor.setSchedConflict 7
# logger.error 6
# FacesUtils.addErrorMessage 10
# ex.getMessage 2
# this.getParticipantProxy 4
# State.MESSAGE_CANCEL.equals 5
# proxy.cancelOperation 5
# State.MESSAGE_COMPENSATE.equals 5
# proxy.compensateOperation 5
# State.MESSAGE_CLOSE.equals 5
# proxy.closeOperation 5
# State.MESSAGE_EXITED.equals 5
# proxy.exitedOperation 5
# State.MESSAGE_FAULTED.equals 5
# proxy.faultedOperation 5
# State.MESSAGE_GETSTATUS.equals 5
# proxy.getStatusOperation 5
# JAXBContext.newInstance 11
# ValidationReport.class 16
# context.createMarshaller 7
# m.setProperty 1
# Marshaller.JAXB_FORMATTED_OUTPUT 10
# m.marshal 1
# System.out.println 6
# getCommunity().add 14
# systemCombo.removeAllItems 11
# systemCombo.addItem 11
# copyBookInterface.getSystems 17
# message.setText 7
# ex.getMessage 2
# message.setCaretPosition 7
# ex.printStackTrace 2
# systems.size 7
# systems.get 7
# systemCombo.addItem 11
# dtls.description 4
# value.equals 5
# value.equals 5
# this.urls 4
# theUrls. 7
# theUrls. 7
# this.urls 4
# UrlHelper.normalize 9
# UrlHelper.normalize 9
# this.urls 4
# response.setHeader 8
# String.format 6
# Calendar.getInstance 8
# expires.add 7
# Calendar.SECOND 8
# response.setHeader 8
# DATE_FORMAT.format 11
# String.format 6
# cSketch.stroke 7
# cSketch.fill 7
# cSketch.rect 7
# cSketch.fill 7
# cSketch.textAlign 7
# p.LEFT 1
# p.BASELINE 1
# cSketch.textFont 7
# p4vj.fontSS14 4
# cSketch.text 7
# System.out.println 6
# instance.getEvtIDs 8
# fail. 4
# prototype." 9
# 1.0 1
# 1.0 1
# GridBagConstraints.CENTER 18
# GridBagConstraints.HORIZONTAL 18
# 100.0 3
# synthesizer.getChannels 11
# cs. 2
# ].controlChange 1
# role.getUsers 4
# users.iterator 5
# iter.hasNext 4
# iter.next 4
# role.getRescs().iterator 4
# iter.hasNext 4
# iter.next 4
# System.out.print 6
# System.out.println 6
# System.currentTimeMillis 6
# e.getSVGDocument 1
# e.getSVGDocument().getURL 1
# e.getSVGDocument().getTitle 1
# !listener.canExit 9
# listener.willExit 8
# logger. 6
# Level.WARNING 5
# ExitListener.willExit 12
# logger. 6
# Level.WARNING 5
# Application.shutdown()" 11
# textLink.contains 8
# ArticleLink.EMAIL_AT_SEPARATOR 11
# !textLink.toLowerCase 9
# Locale.getDefault()).startsWith 6
# wikiFileURL.getWikiFileName 11
# ).contains 1
# ArticleLink.EMAIL_AT_SEPARATOR 11
# this.sliceOffsets 4
# this.rowOffsets 4
# this.columnOffsets 4
# this.sliceOffsets 4
# this.rowOffsets 4
# this.columnOffsets 4
# System.out.println 6
# instance.setChkEvtID 8
# fail. 4
# prototype." 9
# this.converter.convertInteger 4
# this.converter.convertInteger 4
# date.getHour 4
# country1.setCountryId 8
# country1.setCountryName 8
# session.save 7
# countryCode.intValue 11
# generator." 9
# fileSet.getDirectoryScanner 7
# ).getIncludedFiles 1
# files.add 5
# fileSet.getDir 7
# imageCanvas.addMouseListener 11
# imageCanvas.add 11
# SWGFrame.class.getResource 8
# "images/swg.png" 11
# writer.println 6
# writer.flush 6
# reader.readLine().equals 6
# logger.info 6
# socket.getInetAddress 6
# ." 0
# t.start 1
# getServerProcesses().add 20
# .add 0
# )).start 2
# input.readLine 5
# !line.trim().equals 5
# sb. 2
# sb.append 2
# sb.append 2
# input.readLine 5
# sb.toString 2
# System.out.println 6
# instance.getClassification 8
# fail. 4
# prototype." 9
# allItems. 8
# allItems. 8
# optionsMenu.setToolTipText 11
# optionsMenu.setMnemonic 11
# KeyEvent.VK_O 8
# optionsMenu.add 11
# optionsMenu.setEnabled 11
# bar.add 3
# map.put 3
# map.put 3
# map.put 3
# this.organization 4
# map.put 3
# this.organization.acronym 4
# map.put 3
# this.isVisitor 4
# gt.setPageContext 2
# gt.setCookie 2
# gt.setValue 2
# gt.condition 2
# PeerDAOFactory.getInstance().getAccountingDAO().loadBalancesRanking 14
# AccountingConstants.RANKING_SAVING_FREQ 19
# to.setActionName 2
# PeerConstants.SAVE_ACCOUNTING_ACTION_NAME 13
# to.setDelay 2
# to.setTimeUnit 2
# TimeUnit.SECONDS 8
# responses.add 9
# im.getInputFields().iterator 2
# i.hasNext 1
# i.next 1
# field.toString 5
# field.getNormalizedXPath 5
# .startswith 0
# list.add 4
# colMap.get 6
# pkColumns.add 9
# HttpUnitUtils.matches 13
# ].getSource 1
# Command.BACK 7
# PhotoHelp.getInstance 9
# photoOS.close 7
# restTemplate.postForObject 12
# SchemaTO.class 8
# LOG.error 3
# SwingUtilities.invokeLater 14
# newListModel.clear 12
# newListModel.addElement 12
# result.respectCase 6
# result.diploid 6
# toIgnore.add 8
# zipOutput.putNextEntry 9
# IOUtils.copy 7
# zipOutput.closeEntry 9
# this.getStatus 4
# this.nestedCoreException 4
# System.out.println 6
# instance.getCodigo 8
# fail. 4
# prototype." 9
# view.setVisible 4
# mScenarioPanel.remove 14
# mCurrentSmallView.equals 17
# mCurrentBigView.setVisible 15
# mTimeBar.scaleNumberOfPixelsPerPosition 8
# Out.NL 3
# Out.NL 3
# Out.NL 3
# Out.NL 3
# sb.append 2
# "java.util.regex.Matcher" 5
# sb.append 2
# sb.append 2
# sb.append 2
# sb.append 2
# sb.append 2
# sb.append 2
# sb.toString 2
# !locInfo.isVertexLocValid 8
# !locInfo.isVerticalEdgeLocValid 8
# !locInfo.isHorizontalEdgeLocValid 8
# !locInfo.isCellLocValid 8
# lastLocInfo.copy 11
# doc.selectNodes 3
# list.iterator 4
# iter.hasNext 4
# iter.next 4
# element.attributeValue 7
# System.out.println 6
# g.toString 1
# globalDefMap.setValue 12
# System.out.println 6
# e.getMessage 1
# pkg.createCompilationUnit 3
# ".java" 1
# pkg.getElementName 3
# this.getHostname 4
# this.getPort 4
# serverSocket.accept 12
# socket.getInetAddress().getCanonicalHostName 6
# listener.run 8
# Collections.synchronizedMap 11
# _srcModel.entrySet().iterator 9
# itr.hasNext 3
# itr.next 3
# _innerData.put 10
# entry.getKey 5
# entry.getValue 5
# _srcModel.addListDataListener 9
# args.add 4
# currentConnection.driverClass 17
# args.add 4
# currentConnection.url 17
# args.add 4
# currentConnection.user 17
# args.add 4
# currentConnection.password 17
# currentConnection.jar1.trim 17
# args.add 4
# args.add 4
# currentConnection.jar1.trim 17
# currentConnection.jar2.trim 17
# args.add 4
# args.add 4
# currentConnection.jar2.trim 17
# root.removeAllChildren 4
# tree.setModel 4
# tree.setBounds 4
# tree.setLayout 4
# tree.setBackground 4
# Color.white 5
# tree.setCellRenderer 4
# tree.getPathForRow 4
# tree.fireTreeExpanded 4
# _theTemplateFactory.parse 19
# aTemplate.render 9
# getHibernateTemplate().bulkUpdate 22
# getHibernateTemplate().bulkUpdate 22
# getHibernateTemplate().bulkUpdate 22
# getHibernateTemplate().bulkUpdate 22
# cat.debug 3
# String.valueOf 6
# String.valueOf 6
# uid2sid.remove 7
# sid2ssc.remove 7
# sid2ttl.remove 7
# cat.debug 3
# System.out.println 6
# instance.setWelcomeMsg 8
# fail. 4
# prototype." 9
# Command.OK 7
# logger.debug 6
# collection.PID 10
# collection.TITLE 10
# collectionrole.ROLE 14
# collectionrole.USERID 14
# collectionrole.COLLECTIONPID 14
# collection.PID" 10
# collection.ROOT 10
# series.add 6
# collection.addSeries 10
# listener. 8
# DOM. 3
# DOM.setEventListener 3
# file.close 4
# e.printStackTrace 1
# e.printStackTrace 1
# manager.createSession 7
# manager.getSession 7
# manager. 7
# session.getUserId 7
# session.getUserPassword 7
# session.isLoggedIn 7
# e.getMessage 1
# str.endsWith 3
# str.substring 3
# str.indexOf 3
# )).trim 2
# super.messageSent 5
# "/P/X.test" 5
# rfSource.move 8
# serviceManager.getSenderServiceID 14
# to.setWorkerAddress 2
# workerID.toString 8
# to.setWorkerContainerID 2
# workerID.getContainerID 8
# OurGridRequestControl.getInstance 21
# .execute 0
# ... 0
# popup.add 5
# project.getParent 7
# itemsToExpand.add 13
# parent.getParent 6
# treeViewer.setExpandedElements 10
# itemsToExpand.toArray 13
# treeViewer.setSelection 10
# NAG.numberToString 3
# sb.append 2
# sb.append 2
# sb.toString 2
# Command.BACK 7
# pair2startTimeMap.put 17
# clock.getCurrentTime 5
# clock.createNewTimer 5
# removalTimer.addTimerListener 12
# removalTimer.schedule 12
# Time.inMilliseconds 4
# feedItem.getFeed().getFeedId 8
# FeedItem.class 8
# m_statuses.iterator 10
# i.hasNext 1
# )i.next 2
# !eff.isActive 4
# eff.getLock 3
# from.associations 4
# a.destination 1
# association.destination 11
# datamodel.getDisplayName 9
# association.destination 11
# association.getName():"" 11
# m_UnitCombo.setBounds 11
# m_UnitCombo.setModel 11
# m_FreePara.getUnit 10
# m_UnitCombo.setSelectedItem 11
# m_FreePara.getUnit 10
# currentElement.getDirective 14
# values.put 6
# values.put 6
# values.put 6
# mDb.insert 3
# mondrian.olap.Member 8
# ).getMonMember 1
# mondrian.olap.Member 8
# ).getMonMember 1
# monDesc.isCalculatedInQuery 7
# monDesc.equals 7
# monDesc.isChildOrEqualTo 7
# Command.BACK 7
# log.debug 3
# parentFolder.getParent 12
# filesToRemove.contains 13
# services.get 8
# service.unsetContext 7
# services.remove 8
# CServiceEvent.REMOVED 13
# menuItem.getTitle 8
# menuItem.getStock 8
# tmpCourse.getCourseType 9
# Course.FIRST_COURSE 6
# this.setText 4
# m_logo.setVisible 6
# m_login.setText 7
# m_userLabel.setLocation 11
# m_username.setLocation 10
# m_passLabel.setLocation 11
# m_password.setLocation 10
# m_confirmPass.setVisible 13
# m_confPassLabel.setVisible 15
# m_male.setVisible 6
# m_female.setVisible 8
# this.setTitle 4
# Machine.halt 7
# //System.err.println 8
# Lib.assertNotReached 3
# "Machine.halt 8
# label.setText 5
# photo.getSection().getInfoStore().getCaption(photo 5
# JdaiGuiHelpers.reportException 14
# text.equals 4
# label.setIcon 5
# label.setToolTipText 5
# !this.authToken.equals 5
# ServerSettingBean.setSecureMode 17
# serverSettingBean.updateSettings 17
# MainMenuBar.getInstance 11
# dbMgr.getNodeId 5
# cbNE.getSelectedItem 4
# DBDatadesc.SHELF_OLT1 10
# mainMenuBar.putCommand 11
# downloadFile.setViewId 12
# mainMenuBar.getViewId 11
# downloadFile.setVisible 12
# genJarDir.toString 9
# proj.getRequiredBy 4
# null." 4
# fastestGenerators.get 17
# locale.toString 6
# primaryTabMap.keys 13
# tabs.hasMoreElements 4
# tabs.nextElement().getTabpanels().getChildren 4
# list.iterator 4
# itr.hasNext 3
# )itr.next 4
# )tempPanel.getChildren().get 10
# .get 0
# tempView.deregisterView 8
# pcs.firePropertyChange 3
# mMap.get 4
# mMap.containsKey 4
# list.add 4
# mMap.put 4
# LinearDimension.validateSeparationCount 15
# LinearDimension.validateSeparationCount 15
# LinearDimension.validateSeparationCount 15
# LinearDimension.validateSeparationCount 15
# getGeneric(). 12
# getGeneric().addPredicates 12
# getGeneric().save 12
# getGeneric().getSCElement 12
# getGeneric().containsPredicates 12
# getGeneric().getPredicates 12
# EventBAttributes.PREDICATE_ATTRIBUTE 16
# ParseProblem.LexerError 12
# features.getSelectedRows 8
# features.getValueAt 8
# )).booleanValue 2
# features.setValueAt 8
# negativeParseTests. 18
# trees. 5
